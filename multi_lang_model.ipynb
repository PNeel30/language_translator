# %%
import os 

from dotenv import load_dotenv 

load_dotenv()
# Out:
# True

# %%
os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")
#
# File <frozen os>:714, in _Environ.__setitem__(self, key, value)
#     712 def __setitem__(self, key, value):
#     713     key = self.encodekey(key)
# --> 714     value = self.encodevalue(value)
#     715     putenv(key, value)
#     716     self._data[key] = value
#
# File <frozen os>:774, in _create_environ_mapping.<locals>.check_str(value)
#     772 def check_str(value):
#     773     if not isinstance(value, str):
# --> 774         raise TypeError("str expected, not %s" % type(value).__name__)
#     775     return value
#
# TypeError: str expected, not NoneType

# %%
print("GOOGLE_API_KEY set to:", os.environ["GOOGLE_API_KEY"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print("GOOGLE_API_KEY set to:", os.environ["GOOGLE_API_KEY"])
#
# File <frozen os>:709, in _Environ.__getitem__(self, key)
#     706     value = self._data[self.encodekey(key)]
#     707 except KeyError:
#     708     # raise KeyError with the original key value
# --> 709     raise KeyError(key) from None
#     710 return self.decodevalue(value)
#
# KeyError: 'GOOGLE_API_KEY'

# %%
pip install langchain_groq
# Out:
# Collecting langchain_groq
#   Downloading langchain_groq-1.1.2-py3-none-any.whl.metadata (2.4 kB)
# Collecting groq<1.0.0,>=0.30.0 (from langchain_groq)
#   Downloading groq-0.37.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.8 in c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain_groq) (1.2.20)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (4.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (2.12.5)
# Requirement already satisfied: sniffio in c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages (from anyio<5,>=3.5.0->groq<1.0.0,>=0.30.0->langchain_groq) (3.11)
# Requirement already satisfied: certifi in c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain_groq) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain_groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain_groq) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain_groq) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain_groq) (0.7.20)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain_groq) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain_groq) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain_groq) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain_groq) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.8->langchain_groq) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain_groq) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain_groq) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain_groq) (2.32.5)
# Requirement already satisfied: xxhash>=3.0.0 in c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain_groq) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain_groq) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain_groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain_groq) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain_groq) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain_groq) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain_groq) (2.6.2)
# Downloading langchain_groq-1.1.2-py3-none-any.whl (19 kB)
# Downloading groq-0.37.1-py3-none-any.whl (137 kB)
# Installing collected packages: groq, langchain_groq
#
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    -------------------- ------------------- 1/2 [langchain_groq]
#    -------------------- ------------------- 1/2 [langchain_groq]
#    ---------------------------------------- 2/2 [langchain_groq]
#
# Successfully installed groq-0.37.1 langchain_groq-1.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_groq import ChatGroq

model = ChatGroq(
    model="llama-3.3-70b-versatile",
    groq_api_key=os.environ["GROQ_API_KEY"],
)

# %%
model
# Out:
# ChatGoogleGenerativeAI(profile={}, google_api_key=SecretStr('**********'), model='gemini-2.5-Pro', client=<google.genai.client.Client object at 0x0000027CA62EFAC0>, default_metadata=(), model_kwargs={})

# %%
from langchain_core.messages import SystemMessage, HumanMessage

messages=[
    SystemMessage(
        content="Translate the following English text to telugu."
    
    ),
    HumanMessage(
        content="how are you?"
    )
]

# %%
model.invoke(messages)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File c:\Users\ohmp1\AppData\Local\Programs\Python\Python310\lib\site-packages\langchain_google_genai\chat_models.py:3047, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3046 try:
# -> 3047     response: GenerateContentResponse = self.client.models.generate_content(
#    3048         **request,
#    3049     )
#    3050 except ClientError as e:
#
# File c:\Users\ohmp1\AppData\Local\Programs\Python\Python310\lib\site-packages\google\genai\models.py:5709, in Models.generate_content(self, model, contents, config)
#    5708 i += 1
# -> 5709 response = self._generate_content(
#    5710     model=model, contents=contents, config=parsed_config
#    5711 )
#    5713 function_map = _extra_utils.get_function_map(parsed_config)
#
# File c:\Users\ohmp1\AppData\Local\Programs\Python\Python310\lib\site-packages\google\genai\models.py:4371, in Models._generate_content(self, model, contents, config)
#    4369 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4371 response = self._api_client.request(
#    4372     'post', path, request_dict, http_options
#    4373 )
#    4375 if config is not None and getattr(
#    4376     config, 'should_return_http_response', None
#    4377 ):
#
# File c:\Users\ohmp1\AppData\Local\Programs\Python\Python310\lib\site-packages\google\genai\_api_client.py:1401, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1398 http_request = self._build_request(
#    1399     http_method, path, request_dict, http_options
#    1400 )
# -> 1401 response = self._request(http_request, http_options, stream=False)
#    1402 response_body = (
#    1403     response.response_stream[0] if response.response_stream else ''
#    1404 )
#
# File c:\Users\ohmp1\AppData\Local\Programs\Python\Python310\lib\site-packages\google\genai\_api_client.py:1235, in BaseApiClient._request(self, http_request, http_options, stream)
#    1234     retry = tenacity.Retrying(**retry_kwargs)
# -> 1235     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1237 return self._retry(self._request_once, http_request, stream)
#
# File c:\Users\ohmp1\AppData\Local\Programs\Python\Python310\lib\site-packages\tenacity\__init__.py:379, in Retrying.__call__(self, fn, *args, **kwargs)
#     378 while True:
# --> 379     do = self.iter(retry_state=retry_state)
#     380     if isinstance(do, DoAttempt):
#
# File c:\Users\ohmp1\AppData\Local\Programs\Python\Python310\lib\site-packages\tenacity\__init__.py:314, in BaseRetrying.iter(self, retry_state)
#     313 if not (is_explicit_retry or self.retry(retry_state)):
# --> 314     return fut.result()
#     316 if self.after is not None:
#
# File c:\Users\ohmp1\AppData\Local\Programs\Python\Python310\lib\concurrent\futures\_base.py:451, in Future.result(self, timeout)
#     450 elif self._state == FINISHED:
# --> 451     return self.__get_result()
#     453 self._condition.wait(timeout)
#
# File c:\Users\ohmp1\AppData\Local\Programs\Python\Python310\lib\concurrent\futures\_base.py:403, in Future.__get_result(self)
#     402 try:
# --> 403     raise self._exception
#     404 finally:
#     405     # Break a reference cycle with the exception in self._exception
#
# File c:\Users\ohmp1\AppData\Local\Programs\Python\Python310\lib\site-packages\tenacity\__init__.py:382, in Retrying.__call__(self, fn, *args, **kwargs)
#     381 try:
# --> 382     result = fn(*args, **kwargs)
#     383 except BaseException:  # noqa: B902
#
# File c:\Users\ohmp1\AppData\Local\Programs\Python\Python310\lib\site-packages\google\genai\_api_client.py:1214, in BaseApiClient._request_once(self, http_request, stream)
#    1207 response = self._httpx_client.request(
#    1208     method=http_request.method,
#    1209     url=http_request.url,
#    (...)
#    1212     timeout=http_request.timeout,
#    1213 )
# -> 1214 errors.APIError.raise_for_response(response)
#    1215 return HttpResponse(
#    1216     response.headers, response if stream else [response.text]
#    1217 )
#
# File c:\Users\ohmp1\AppData\Local\Programs\Python\Python310\lib\site-packages\google\genai\errors.py:134, in APIError.raise_for_response(cls, response)
#     132   response_json = response.body_segments[0].get('error', {})
# --> 134 cls.raise_error(response.status_code, response_json, response)
#
# File c:\Users\ohmp1\AppData\Local\Programs\Python\Python310\lib\site-packages\google\genai\errors.py:159, in APIError.raise_error(cls, status_code, response_json, response)
#     158 if 400 <= status_code < 500:
# --> 159   raise ClientError(status_code, response_json, response)
#     160 elif 500 <= status_code < 600:
#
# ClientError: 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': '* GenerateContentRequest.model: unexpected model name format\n', 'status': 'INVALID_ARGUMENT'}}
#
# The above exception was the direct cause of the following exception:
#
# ChatGoogleGenerativeAIError               Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 model.invoke(messages)
#
# File c:\Users\ohmp1\AppData\Local\Programs\Python\Python310\lib\site-packages\langchain_google_genai\chat_models.py:2535, in ChatGoogleGenerativeAI.invoke(self, input, config, code_execution, stop, **kwargs)
#    2532         msg = "Tools are already defined.code_execution tool can't be defined"
#    2533         raise ValueError(msg)
# -> 2535 return super().invoke(input, config, stop=stop, **kwargs)
#
# File c:\Users\ohmp1\AppData\Local\Programs\Python\Python310\lib\site-packages\langchain_core\language_models\chat_models.py:402, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     388 @override
#     389 def invoke(
#     390     self,
#    (...)
#     395     **kwargs: Any,
#     396 ) -> AIMessage:
#     397     config = ensure_config(config)
#     398     return cast(
#     399         "AIMessage",
#     400         cast(
#     401             "ChatGeneration",
# --> 402             self.generate_prompt(
#     403                 [self._convert_input(input)],
#     404                 stop=stop,
#     405                 callbacks=config.get("callbacks"),
#     406                 tags=config.get("tags"),
#     407                 metadata=config.get("metadata"),
#     408                 run_name=config.get("run_name"),
#     409                 run_id=config.pop("run_id", None),
#     410                 **kwargs,
#     411             ).generations[0][0],
#     412         ).message,
#     413     )
#
# File c:\Users\ohmp1\AppData\Local\Programs\Python\Python310\lib\site-packages\langchain_core\language_models\chat_models.py:1123, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1114 @override
#    1115 def generate_prompt(
#    1116     self,
#    (...)
#    1120     **kwargs: Any,
#    1121 ) -> LLMResult:
#    1122     prompt_messages = [p.to_messages() for p in prompts]
# -> 1123     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\ohmp1\AppData\Local\Programs\Python\Python310\lib\site-packages\langchain_core\language_models\chat_models.py:933, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     930 for i, m in enumerate(input_messages):
#     931     try:
#     932         results.append(
# --> 933             self._generate_with_cache(
#     934                 m,
#     935                 stop=stop,
#     936                 run_manager=run_managers[i] if run_managers else None,
#     937                 **kwargs,
#     938             )
#     939         )
#     940     except BaseException as e:
#     941         if run_managers:
#
# File c:\Users\ohmp1\AppData\Local\Programs\Python\Python310\lib\site-packages\langchain_core\language_models\chat_models.py:1235, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1233     result = generate_from_stream(iter(chunks))
#    1234 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1235     result = self._generate(
#    1236         messages, stop=stop, run_manager=run_manager, **kwargs
#    1237     )
#    1238 else:
#    1239     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\ohmp1\AppData\Local\Programs\Python\Python310\lib\site-packages\langchain_google_genai\chat_models.py:3051, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3047     response: GenerateContentResponse = self.client.models.generate_content(
#    3048         **request,
#    3049     )
#    3050 except ClientError as e:
# -> 3051     _handle_client_error(e, request)
#    3053 return _response_to_result(response)
#
# File c:\Users\ohmp1\AppData\Local\Programs\Python\Python310\lib\site-packages\langchain_google_genai\chat_models.py:145, in _handle_client_error(e, request)
#     143 model_name = request.get("model", "unknown")
#     144 msg = f"Error calling model '{model_name}' ({e.status}): {e}"
# --> 145 raise ChatGoogleGenerativeAIError(msg) from e
#
# ChatGoogleGenerativeAIError: Error calling model 'gemini-2.5-Pro' (INVALID_ARGUMENT): 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': '* GenerateContentRequest.model: unexpected model name format\n', 'status': 'INVALID_ARGUMENT'}}

# %%
response=model.invoke(messages)

# %%
type(response)
# Out:
# langchain_core.messages.ai.AIMessage

# %%
from langchain_core.output_parsers import StrOutputParser

parser=StrOutputParser()

result=parser.invoke(response)

print(result)
# Out:
# మీరు ఎలా ఉన్నారు? (Mēru elā unnaru?)
#
#
# This is the most common way to say "How are you?" in Telugu.

# %% [markdown]
# # USING LCEL--> Langchain Expression Language
# It is a simple and flexible way to build LLM (Large Language Model) pipelines using chain-like syntax in LangChain.LCEL lets you connect prompts, models, tools, and logic like Lego blocks — all in one clean, readable line of code.

# %%
chain=model | parser

chain.invoke(messages)
# Out:
# 'మీరు ఎలా ఉన్నారు? (Meeru ela unnaru?) \n'

# %% [markdown]
# # Instead of giving the model a list of messages everytime, we can use prompt templates

# %%
from langchain_core.prompts import ChatPromptTemplate

generic_template="Translate the folowing into {language}."

prompt=ChatPromptTemplate.from_messages(
    [("system", generic_template), ("user", "{text}")],
)

# %%
prompt.invoke({
    "language":"telugu",
    "text":"how are you?"
})
# Out:
# ChatPromptValue(messages=[SystemMessage(content='Translate the folowing into telugu.', additional_kwargs={}, response_metadata={}), HumanMessage(content='how are you?', additional_kwargs={}, response_metadata={})])

# %%
result=prompt.invoke({
    "language":"telugu",
    "text":"how are you?"
})

# %%
result.to_messages()
# Out:
# [SystemMessage(content='Translate the folowing into telugu.', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='how are you?', additional_kwargs={}, response_metadata={})]

# %% [markdown]
# # Using LCEL with three components prompt, model and parser

# %%
chain=prompt | model | parser

chain.invoke({
    "language":"telugu",
    "text":"how are you?"
})
# Out:
# 'మీకు ఎలా ఉన్నారు? (Mēku elā unnaru?) \n\n\nThis is the most common way to ask "how are you?" in Telugu. \n'
